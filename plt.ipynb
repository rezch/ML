# %% [markdown]
# # Missing values

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = (df.isna().sum().to_frame()/len(df)*100).astype('int32')
data.loc[12] = 100

fig, ax = plt.subplots(figsize=[10, 7])
plt.title('Missing Value Status',fontweight='bold')
ax = sns.heatmap(data,annot=True,fmt='d', cmap='plasma')
ax.set_xlabel('Amount Missing')
plt.show()

# %% [markdown]
# # outliers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
colours = ["#D0DBEE", "#C2C4E2", "#EED4E5", "#D1E6DC", "#BDE2E2"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = features,palette = colours)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # corr map

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=[12, 9])
plt.title("Correlation heatmap")

ax = sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='plasma')

ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)

plt.show()

# %% [markdown]
# # hist

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tenure = df['tenure']
fig, ax = plt.subplots(figsize=[10, 8])
plt.title("How many month people has been a client")

sns.histplot(tenure, bins=50, alpha=0.2)

plt.xticks(list(range(0, tenure.max(), 5)), fontsize=12)
plt.yticks(list(range(0, 550, 30)), fontsize=12)
plt.xlabel('Number of months', fontsize=16)
plt.ylabel('Number of clients', fontsize=16)

plt.show()

# %% [markdown]
# # columns importance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
feats = {}
for feature, importance in zip(df.columns, RF['RF'].featureimportances):
    feats[feature] = importance
data = pd.DataFrame.from_dict(feats, orient='index').sort_values(0)


fig, ax = plt.subplots(figsize=[10,10])

ax = sns.barplot(x=data[0], y=data.index, data=data, color='skyblue')

plt.show()
